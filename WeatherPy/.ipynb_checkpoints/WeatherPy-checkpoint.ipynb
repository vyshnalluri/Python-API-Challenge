# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#print(weather_api_key)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

#creating empty lists
city_id = []
city_name = []
country_name = []
cloudiness = []
temperature = []
lat = []
long = []
humidity = []
wind_speed = []
max_temperature = []


#idx = 0

for city in cities:
    #print(city)
    
    response = requests.get(query_url+city).json()
    pprint(response)
    try:
        #print(response["name"])
        city_id.append(response["id"])
        city_name.append(response["name"])
        #added the country list while doing vacationpy
        country_name.append(response["sys"]["country"])
        cloudiness.append(response["clouds"]["all"])
        temperature.append(response["main"]["temp"])
        max_temperature.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        long.append(response["coord"]["lon"])
        humidity.append(response["main"]["humidity"])
        wind_speed.append(response["wind"]["speed"])
        print(f"City Name: {response['name']}, City ID: {response['id']}")
        #print(city_id_list)
        #print(city_name_list)
    except KeyError:
        print(f"The city {city} not found.")
    
#     idx = idx+1
#     if idx ==10:
#         break;
# Out:
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -20.5167, 'lon': 57.5167},
#  'dt': 1627403560,
#  'id': 933995,
#  'main': {'feels_like': 67.35,
#           'humidity': 94,
#           'pressure': 1020,
#           'temp': 66.58,
#           'temp_max': 66.58,
#           'temp_min': 66.36},
#  'name': 'Souillac',
#  'rain': {'1h': 2.59},
#  'sys': {'country': 'MU',
#          'id': 2061,
#          'sunrise': 1627353749,
#          'sunset': 1627393809,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 5000,
#  'weather': [{'description': 'light intensity shower rain',
#               'icon': '09n',
#               'id': 520,
#               'main': 'Rain'}],
#  'wind': {'deg': 140, 'speed': 8.05}}
# City Name: Souillac, City ID: 933995
# {'base': 'stations',
#  'clouds': {'all': 93},
#  'cod': 200,
#  'coord': {'lat': 46.4856, 'lon': 135.8833},
#  'dt': 1627403561,
#  'id': 2013279,
#  'main': {'feels_like': 71.47,
#           'grnd_level': 938,
#           'humidity': 84,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 70.75,
#           'temp_max': 70.75,
#           'temp_min': 70.75},
#  'name': 'Vostok',
#  'sys': {'country': 'RU', 'sunrise': 1627414330, 'sunset': 1627468411},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 135, 'gust': 2.84, 'speed': 3.13}}
# City Name: Vostok, City ID: 2013279
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 37.1041, 'lon': -113.5841},
#  'dt': 1627403927,
#  'id': 5546220,
#  'main': {'feels_like': 85.95,
#           'humidity': 63,
#           'pressure': 1018,
#           'temp': 82.6,
#           'temp_max': 87.53,
#           'temp_min': 79.39},
#  'name': 'Saint George',
#  'sys': {'country': 'US',
#          'id': 2007591,
#          'sunrise': 1627389325,
#          'sunset': 1627440361,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 242, 'gust': 5.01, 'speed': 1.99}}
# City Name: Saint George, City ID: 5546220
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 73.5069, 'lon': 80.5464},
#  'dt': 1627403483,
#  'id': 1507390,
#  'main': {'feels_like': 55.62,
#           'grnd_level': 986,
#           'humidity': 89,
#           'pressure': 991,
#           'sea_level': 991,
#           'temp': 56.12,
#           'temp_max': 56.12,
#           'temp_min': 56.12},
#  'name': 'Dikson',
#  'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 130, 'gust': 18.37, 'speed': 16.91}}
# City Name: Dikson, City ID: 1507390
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -54.8, 'lon': -68.3},
#  'dt': 1627403483,
#  'id': 3833367,
#  'main': {'feels_like': 37.06,
#           'humidity': 87,
#           'pressure': 1022,
#           'temp': 37.06,
#           'temp_max': 37.06,
#           'temp_min': 37.02},
#  'name': 'Ushuaia',
#  'sys': {'country': 'AR',
#          'id': 8303,
#          'sunrise': 1627389024,
#          'sunset': 1627418926,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 0}}
# City Name: Ushuaia, City ID: 3833367
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -26.6481, 'lon': 15.1594},
#  'dt': 1627403561,
#  'id': 3355672,
#  'main': {'feels_like': 57.58,
#           'grnd_level': 1016,
#           'humidity': 77,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 58.42,
#           'temp_max': 58.42,
#           'temp_min': 58.42},
#  'name': 'Lüderitz',
#  'sys': {'country': 'NA', 'sunrise': 1627364517, 'sunset': 1627403372},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 172, 'gust': 18.97, 'speed': 13.13}}
# City Name: Lüderitz, City ID: 3355672
# {'base': 'stations',
#  'clouds': {'all': 94},
#  'cod': 200,
#  'coord': {'lat': 60.7522, 'lon': -137.5108},
#  'dt': 1627403561,
#  'id': 5969025,
#  'main': {'feels_like': 49.95,
#           'humidity': 87,
#           'pressure': 1019,
#           'temp': 49.95,
#           'temp_max': 49.95,
#           'temp_min': 49.95},
#  'name': 'Haines Junction',
#  'sys': {'country': 'CA',
#          'id': 287,
#          'sunrise': 1627389273,
#          'sunset': 1627451898,
#          'type': 1},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 1.14}}
# City Name: Haines Junction, City ID: 5969025
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -46.1927, 'lon': 168.8643},
#  'dt': 1627403562,
#  'id': 6201424,
#  'main': {'feels_like': 48.47,
#           'grnd_level': 1003,
#           'humidity': 90,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 48.47,
#           'temp_max': 48.47,
#           'temp_min': 48.47},
#  'name': 'Mataura',
#  'sys': {'country': 'NZ',
#          'id': 2008959,
#          'sunrise': 1627416593,
#          'sunset': 1627450318,
#          'type': 2},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 239, 'gust': 5.41, 'speed': 1.86}}
# City Name: Mataura, City ID: 6201424
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 55.7435, 'lon': -97.8558},
#  'dt': 1627403562,
#  'id': 6165406,
#  'main': {'feels_like': 69.3,
#           'humidity': 56,
#           'pressure': 1011,
#           'temp': 69.96,
#           'temp_max': 69.96,
#           'temp_min': 69.96},
#  'name': 'Thompson',
#  'sys': {'country': 'CA',
#          'id': 935,
#          'sunrise': 1627381693,
#          'sunset': 1627440444,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'speed': 5.75}}
# City Name: Thompson, City ID: 6165406
# {'base': 'stations',
#  'clouds': {'all': 17},
#  'cod': 200,
#  'coord': {'lat': -9.1061, 'lon': 124.8925},
#  'dt': 1627403562,
#  'id': 1651103,
#  'main': {'feels_like': 70.14,
#           'grnd_level': 974,
#           'humidity': 86,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 69.46,
#           'temp_max': 69.46,
#           'temp_min': 69.46},
#  'name': 'Atambua',
#  'sys': {'country': 'ID', 'sunrise': 1627422955, 'sunset': 1627465062},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 137, 'gust': 5.06, 'speed': 4.7}}
# City Name: Atambua, City ID: 1651103
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 53.596, 'lon': 19.5685},
#  'dt': 1627403956,
#  'id': 3097902,
#  'main': {'feels_like': 79.79,
#           'grnd_level': 999,
#           'humidity': 62,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 79.79,
#           'temp_max': 79.79,
#           'temp_min': 71.85},
#  'name': 'Iława',
#  'sys': {'country': 'PL',
#          'id': 2007860,
#          'sunrise': 1627354126,
#          'sunset': 1627411647,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 272, 'gust': 9.51, 'speed': 4.18}}
# City Name: Iława, City ID: 3097902
# {'cod': '404', 'message': 'city not found'}
# The city rolim de moura not found.
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 69.7008, 'lon': 170.3133},
#  'dt': 1627403957,
#  'id': 2122090,
#  'main': {'feels_like': 23.97,
#           'grnd_level': 997,
#           'humidity': 93,
#           'pressure': 1003,
#           'sea_level': 1003,
#           'temp': 33.91,
#           'temp_max': 33.91,
#           'temp_min': 33.91},
#  'name': 'Pevek',
#  'sys': {'country': 'RU', 'sunrise': 1627392834, 'sunset': 1627473382},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 349, 'gust': 16.49, 'speed': 15.19}}
# City Name: Pevek, City ID: 2122090
# {'cod': '404', 'message': 'city not found'}
# The city burkhala not found.
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 22.0752, 'lon': -159.319},
#  'dt': 1627403833,
#  'id': 5848280,
#  'main': {'feels_like': 74.68,
#           'humidity': 83,
#           'pressure': 1018,
#           'temp': 73.71,
#           'temp_max': 79.12,
#           'temp_min': 71.47},
#  'name': 'Kapaa',
#  'sys': {'country': 'US',
#          'id': 2001562,
#          'sunrise': 1627402056,
#          'sunset': 1627449583,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 50, 'speed': 12.66}}
# City Name: Kapaa, City ID: 5848280
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 46.8083, 'lon': -100.7837},
#  'dt': 1627403957,
#  'id': 5688025,
#  'main': {'feels_like': 82.47,
#           'humidity': 61,
#           'pressure': 1015,
#           'temp': 80.44,
#           'temp_max': 80.44,
#           'temp_min': 77.86},
#  'name': 'Bismarck',
#  'sys': {'country': 'US',
#          'id': 3441,
#          'sunrise': 1627384643,
#          'sunset': 1627438899,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 90, 'speed': 9.22}}
# City Name: Bismarck, City ID: 5688025
# {'base': 'stations',
#  'clouds': {'all': 67},
#  'cod': 200,
#  'coord': {'lat': 2.0167, 'lon': 112.9333},
#  'dt': 1627403957,
#  'id': 1737185,
#  'main': {'feels_like': 75.47,
#           'grnd_level': 1006,
#           'humidity': 97,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 73.83,
#           'temp_max': 73.83,
#           'temp_min': 73.83},
#  'name': 'Kapit',
#  'sys': {'country': 'MY', 'sunrise': 1627424901, 'sunset': 1627468857},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 179, 'gust': 1.39, 'speed': 1.32}}
# City Name: Kapit, City ID: 1737185
# {'base': 'stations',
#  'clouds': {'all': 13},
#  'cod': 200,
#  'coord': {'lat': -14.8796, 'lon': 47.9875},
#  'dt': 1627403958,
#  'id': 1068971,
#  'main': {'feels_like': 73.65,
#           'grnd_level': 1015,
#           'humidity': 54,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 74.01,
#           'temp_max': 74.01,
#           'temp_min': 74.01},
#  'name': 'Antsohihy',
#  'sys': {'country': 'MG', 'sunrise': 1627355521, 'sunset': 1627396611},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 121, 'gust': 21.34, 'speed': 9.44}}
# City Name: Antsohihy, City ID: 1068971
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 63.4427, 'lon': -20.2734},
#  'dt': 1627403958,
#  'id': 3412093,
#  'main': {'feels_like': 57.33,
#           'humidity': 77,
#           'pressure': 1010,
#           'temp': 58.19,
#           'temp_max': 58.19,
#           'temp_min': 58.19},
#  'name': 'Vestmannaeyjar',
#  'sys': {'country': 'IS',
#          'id': 93,
#          'sunrise': 1627359613,
#          'sunset': 1627425285,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 300, 'speed': 4.61}}
# City Name: Vestmannaeyjar, City ID: 3412093
# {'base': 'stations',
#  'clouds': {'all': 30},
#  'cod': 200,
#  'coord': {'lat': -34.5322, 'lon': 20.0403},
#  'dt': 1627403958,
#  'id': 1015776,
#  'main': {'feels_like': 60.21,
#           'humidity': 51,
#           'pressure': 1012,
#           'temp': 61.92,
#           'temp_max': 61.92,
#           'temp_min': 61.92},
#  'name': 'Bredasdorp',
#  'sys': {'country': 'ZA',
#          'id': 1966,
#          'sunrise': 1627364233,
#          'sunset': 1627401313,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 340, 'speed': 20.71}}
# City Name: Bredasdorp, City ID: 1015776
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 44.3945, 'lon': -1.1672},
#  'dt': 1627403958,
#  'id': 3032556,
#  'main': {'feels_like': 71.76,
#           'humidity': 68,
#           'pressure': 1015,
#           'temp': 71.69,
#           'temp_max': 78.19,
#           'temp_min': 68.49},
#  'name': 'Biscarrosse',
#  'sys': {'country': 'FR',
#          'id': 6448,
#          'sunrise': 1627361173,
#          'sunset': 1627414553,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 8.05}}
# City Name: Biscarrosse, City ID: 3032556
# {'cod': '404', 'message': 'city not found'}
# The city taolanaro not found.
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 57.79, 'lon': -152.4072},
#  'dt': 1627403959,
#  'id': 5866583,
#  'main': {'feels_like': 53.44,
#           'humidity': 71,
#           'pressure': 1018,
#           'temp': 54.91,
#           'temp_max': 54.91,
#           'temp_min': 54.91},
#  'name': 'Saint Paul Harbor',
#  'sys': {'country': 'US',
#          'id': 7668,
#          'sunrise': 1627394095,
#          'sunset': 1627454226,
#          'type': 1},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 250, 'speed': 3.44}}
# City Name: Saint Paul Harbor, City ID: 5866583
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -38.0023, 'lon': -57.5575},
#  'dt': 1627403852,
#  'id': 3430863,
#  'main': {'feels_like': 42.82,
#           'humidity': 58,
#           'pressure': 1008,
#           'temp': 46.76,
#           'temp_max': 48.99,
#           'temp_min': 44.62},
#  'name': 'Mar del Plata',
#  'sys': {'country': 'AR',
#          'id': 264934,
#          'sunrise': 1627383293,
#          'sunset': 1627419500,
#          'type': 2},
#  'timezone': -10800,
#  'visibility': 5000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 41, 'gust': 20, 'speed': 8.01}}
# City Name: Mar del Plata, City ID: 3430863
# {'base': 'stations',
#  'clouds': {'all': 31},
#  'cod': 200,
#  'coord': {'lat': 43.3552, 'lon': 77.4525},
#  'dt': 1627403959,
#  'id': 1523741,
#  'main': {'feels_like': 74.46,
#           'grnd_level': 896,
#           'humidity': 57,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 74.62,
#           'temp_max': 74.62,
#           'temp_min': 74.62},
#  'name': 'Esik',
#  'sys': {'country': 'KZ',
#          'id': 8818,
#          'sunrise': 1627342475,
#          'sunset': 1627395514,
#          'type': 1},
#  'timezone': 21600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 199, 'gust': 4.65, 'speed': 5.01}}
# City Name: Esik, City ID: 1523741
# {'base': 'stations',
#  'clouds': {'all': 35},
#  'cod': 200,
#  'coord': {'lat': -20.2333, 'lon': 164.0167},
#  'dt': 1627403959,
#  'id': 2138555,
#  'main': {'feels_like': 69.17,
#           'grnd_level': 1018,
#           'humidity': 69,
#           'pressure': 1018,
#           'sea_level': 1018,
#           'temp': 69.3,
#           'temp_max': 69.3,
#           'temp_min': 69.3},
#  'name': 'Poum',
#  'sys': {'country': 'NC', 'sunrise': 1627414547, 'sunset': 1627454691},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 125, 'gust': 13.58, 'speed': 12.03}}
# City Name: Poum, City ID: 2138555
# {'base': 'stations',
#  'clouds': {'all': 48},
#  'cod': 200,
#  'coord': {'lat': 65.6145, 'lon': -37.6368},
#  'dt': 1627403890,
#  'id': 3424607,
#  'main': {'feels_like': 39.9,
#           'grnd_level': 1019,
#           'humidity': 82,
#           'pressure': 1024,
#           'sea_level': 1024,
#           'temp': 42.96,
#           'temp_max': 42.96,
#           'temp_min': 42.96},
#  'name': 'Tasiilaq',
#  'sys': {'country': 'GL',
#          'id': 81,
#          'sunrise': 1627362199,
#          'sunset': 1627431032,
#          'type': 1},
#  'timezone': -7200,
#  'visibility': 1449,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 264, 'gust': 6.49, 'speed': 5.08}}
# City Name: Tasiilaq, City ID: 3424607
# {'base': 'stations',
#  'clouds': {'all': 97},
#  'cod': 200,
#  'coord': {'lat': -23.1203, 'lon': -134.9692},
#  'dt': 1627403960,
#  'id': 4030556,
#  'main': {'feels_like': 74.8,
#           'grnd_level': 1016,
#           'humidity': 76,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 74.12,
#           'temp_max': 74.12,
#           'temp_min': 74.12},
#  'name': 'Rikitea',
#  'sys': {'country': 'PF', 'sunrise': 1627400182, 'sunset': 1627439769},
#  'timezone': -32400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 1, 'gust': 18.32, 'speed': 16.31}}
# City Name: Rikitea, City ID: 4030556
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 64.8378, 'lon': -147.7164},
#  'dt': 1627403803,
#  'id': 5861897,
#  'main': {'feels_like': 55.47,
#           'humidity': 83,
#           'pressure': 1013,
#           'temp': 56.25,
#           'temp_max': 60.1,
#           'temp_min': 53.92},
#  'name': 'Fairbanks',
#  'sys': {'country': 'US',
#          'id': 2017395,
#          'sunrise': 1627389306,
#          'sunset': 1627456764,
#          'type': 2},
#  'timezone': -28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 210, 'speed': 3.44}}
# City Name: Fairbanks, City ID: 5861897
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -30.2752, 'lon': -57.6007},
#  'dt': 1627403960,
#  'id': 3443631,
#  'main': {'feels_like': 48.9,
#           'grnd_level': 1019,
#           'humidity': 36,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 52.29,
#           'temp_max': 52.29,
#           'temp_min': 52.29},
#  'name': 'Bella Union',
#  'sys': {'country': 'UY', 'sunrise': 1627382362, 'sunset': 1627420452},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'gust': 23.55, 'speed': 14.47}}
# City Name: Bella Union, City ID: 3443631
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -33.918, 'lon': 25.5701},
#  'dt': 1627403820,
#  'id': 964420,
#  'main': {'feels_like': 75.65,
#           'humidity': 20,
#           'pressure': 1011,
#           'temp': 77.29,
#           'temp_max': 77.29,
#           'temp_min': 65.1},
#  'name': 'Port Elizabeth',
#  'sys': {'country': 'ZA',
#          'id': 1973,
#          'sunrise': 1627362832,
#          'sunset': 1627400060,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320, 'speed': 9.22}}
# City Name: Port Elizabeth, City ID: 964420
# {'cod': '404', 'message': 'city not found'}
# The city chagda not found.
# {'cod': '404', 'message': 'city not found'}
# The city lolua not found.
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': 63.8567, 'lon': 57.3094},
#  'dt': 1627403960,
#  'id': 470905,
#  'main': {'feels_like': 40.26,
#           'grnd_level': 992,
#           'humidity': 92,
#           'pressure': 1004,
#           'sea_level': 1004,
#           'temp': 45.64,
#           'temp_max': 45.64,
#           'temp_min': 45.64},
#  'name': 'Vuktyl',
#  'sys': {'country': 'RU', 'sunrise': 1627340683, 'sunset': 1627406974},
#  'timezone': 10800,
#  'visibility': 8714,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 293, 'gust': 21.72, 'speed': 11.05}}
# City Name: Vuktyl, City ID: 470905
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -37.6167, 'lon': -73.65},
#  'dt': 1627403630,
#  'id': 3883457,
#  'main': {'feels_like': 41.94,
#           'grnd_level': 1025,
#           'humidity': 65,
#           'pressure': 1029,
#           'sea_level': 1029,
#           'temp': 49.17,
#           'temp_max': 49.17,
#           'temp_min': 49.17},
#  'name': 'Lebu',
#  'sys': {'country': 'CL', 'sunrise': 1627387102, 'sunset': 1627423416},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 181, 'gust': 32.93, 'speed': 23.2}}
# City Name: Lebu, City ID: 3883457
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': 20.8667, 'lon': -90.4},
#  'dt': 1627403961,
#  'id': 3531368,
#  'main': {'feels_like': 93.43,
#           'grnd_level': 1015,
#           'humidity': 64,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 86.4,
#           'temp_max': 86.4,
#           'temp_min': 86.4},
#  'name': 'Celestún',
#  'sys': {'country': 'MX', 'sunrise': 1627385630, 'sunset': 1627432928},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 230, 'gust': 8.55, 'speed': 8.39}}
# City Name: Celestún, City ID: 3531368
# {'base': 'stations',
#  'clouds': {'all': 92},
#  'cod': 200,
#  'coord': {'lat': -33.65, 'lon': 115.3333},
#  'dt': 1627403961,
#  'id': 2075265,
#  'main': {'feels_like': 40.44,
#           'grnd_level': 1010,
#           'humidity': 63,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 46.04,
#           'temp_max': 47.08,
#           'temp_min': 46.04},
#  'name': 'Busselton',
#  'sys': {'country': 'AU',
#          'id': 2020551,
#          'sunrise': 1627427625,
#          'sunset': 1627464980,
#          'type': 2},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 268, 'gust': 19.24, 'speed': 11.99}}
# City Name: Busselton, City ID: 2075265
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 71.2906, 'lon': -156.7887},
#  'dt': 1627403629,
#  'id': 5880054,
#  'main': {'feels_like': 38.59,
#           'humidity': 87,
#           'pressure': 1006,
#           'temp': 42.82,
#           'temp_max': 42.82,
#           'temp_min': 42.82},
#  'name': 'Barrow',
#  'sys': {'country': 'US', 'id': 7649, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': -28800,
#  'visibility': 402,
#  'weather': [{'description': 'fog', 'icon': '50n', 'id': 741, 'main': 'Fog'}],
#  'wind': {'deg': 90, 'speed': 6.91}}
# City Name: Barrow, City ID: 5880054
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -53.15, 'lon': -70.9167},
#  'dt': 1627403903,
#  'id': 3874787,
#  'main': {'feels_like': 37.11,
#           'humidity': 87,
#           'pressure': 1025,
#           'temp': 42.53,
#           'temp_max': 42.91,
#           'temp_min': 41.02},
#  'name': 'Punta Arenas',
#  'rain': {'1h': 0.25},
#  'sys': {'country': 'CL',
#          'id': 8487,
#          'sunrise': 1627389222,
#          'sunset': 1627419984,
#          'type': 1},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 320, 'speed': 9.22}}
# City Name: Punta Arenas, City ID: 3874787
# {'base': 'stations',
#  'clouds': {'all': 9},
#  'cod': 200,
#  'coord': {'lat': 42.6001, 'lon': -73.9662},
#  'dt': 1627403944,
#  'id': 5106841,
#  'main': {'feels_like': 84.88,
#           'humidity': 59,
#           'pressure': 1012,
#           'temp': 82.45,
#           'temp_max': 86.61,
#           'temp_min': 78.39},
#  'name': 'Albany',
#  'sys': {'country': 'US',
#          'id': 19530,
#          'sunrise': 1627378970,
#          'sunset': 1627431699,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 278, 'gust': 11.43, 'speed': 3.91}}
# City Name: Albany, City ID: 5106841
# {'cod': '404', 'message': 'city not found'}
# The city grand river south east not found.
# {'base': 'stations',
#  'clouds': {'all': 77},
#  'cod': 200,
#  'coord': {'lat': -6.2222, 'lon': -57.7528},
#  'dt': 1627403961,
#  'id': 3397763,
#  'main': {'feels_like': 96.89,
#           'grnd_level': 1003,
#           'humidity': 23,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 98.69,
#           'temp_max': 98.69,
#           'temp_min': 98.69},
#  'name': 'Jacareacanga',
#  'sys': {'country': 'BR', 'sunrise': 1627380152, 'sunset': 1627422736},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 128, 'gust': 7.02, 'speed': 3.74}}
# City Name: Jacareacanga, City ID: 3397763
# {'cod': '404', 'message': 'city not found'}
# The city galiwinku not found.
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 53.0452, 'lon': 158.6483},
#  'dt': 1627403962,
#  'id': 2122104,
#  'main': {'feels_like': 63.07,
#           'humidity': 82,
#           'pressure': 1004,
#           'temp': 63.19,
#           'temp_max': 63.19,
#           'temp_min': 63.19},
#  'name': 'Petropavlovsk-Kamchatskiy',
#  'sys': {'country': 'RU',
#          'id': 8887,
#          'sunrise': 1627407357,
#          'sunset': 1627464457,
#          'type': 1},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 350, 'speed': 8.95}}
# City Name: Petropavlovsk-Kamchatskiy, City ID: 2122104
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -3.8004, 'lon': 102.2655},
#  'dt': 1627403962,
#  'id': 1649150,
#  'main': {'feels_like': 76.1,
#           'grnd_level': 1009,
#           'humidity': 83,
#           'pressure': 1011,
#           'sea_level': 1011,
#           'temp': 75,
#           'temp_max': 75,
#           'temp_min': 75},
#  'name': 'Bengkulu',
#  'sys': {'country': 'ID', 'sunrise': 1627341546, 'sunset': 1627384532},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 79, 'gust': 7.16, 'speed': 5.06}}
# City Name: Bengkulu, City ID: 1649150
# {'base': 'stations',
#  'clouds': {'all': 88},
#  'cod': 200,
#  'coord': {'lat': -42.8794, 'lon': 147.3294},
#  'dt': 1627403922,
#  'id': 2163355,
#  'main': {'feels_like': 52.79,
#           'humidity': 63,
#           'pressure': 986,
#           'temp': 54.66,
#           'temp_max': 57.25,
#           'temp_min': 51.26},
#  'name': 'Hobart',
#  'sys': {'country': 'AU',
#          'id': 2002195,
#          'sunrise': 1627421205,
#          'sunset': 1627456043,
#          'type': 2},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 45, 'gust': 8.99, 'speed': 5.01}}
# City Name: Hobart, City ID: 2163355
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 17.0151, 'lon': 54.0924},
#  'dt': 1627403962,
#  'id': 286621,
#  'main': {'feels_like': 87.39,
#           'humidity': 89,
#           'pressure': 1003,
#           'temp': 80.69,
#           'temp_max': 80.69,
#           'temp_min': 80.69},
#  'name': 'Salalah',
#  'sys': {'country': 'OM',
#          'id': 7562,
#          'sunrise': 1627351311,
#          'sunset': 1627397891,
#          'type': 1},
#  'timezone': 14400,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 170, 'speed': 5.75}}
# City Name: Salalah, City ID: 286621
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': -22.6667, 'lon': 167.4833},
#  'dt': 1627403962,
#  'id': 2137773,
#  'main': {'feels_like': 67.24,
#           'grnd_level': 1009,
#           'humidity': 57,
#           'pressure': 1019,
#           'sea_level': 1019,
#           'temp': 68.05,
#           'temp_max': 68.05,
#           'temp_min': 68.05},
#  'name': 'Vao',
#  'sys': {'country': 'NC', 'sunrise': 1627413945, 'sunset': 1627453628},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 121, 'gust': 16.15, 'speed': 15.77}}
# City Name: Vao, City ID: 2137773
# {'base': 'stations',
#  'clouds': {'all': 53},
#  'cod': 200,
#  'coord': {'lat': -16.7833, 'lon': -151.5},
#  'dt': 1627403457,
#  'id': 4033375,
#  'main': {'feels_like': 78.67,
#           'grnd_level': 1015,
#           'humidity': 77,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 77.59,
#           'temp_max': 77.59,
#           'temp_min': 77.59},
#  'name': 'Tevaitoa',
#  'rain': {'1h': 0.88},
#  'sys': {'country': 'PF', 'sunrise': 1627403558, 'sunset': 1627444328},
#  'timezone': -36000,
#  'visibility': 8661,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 359, 'gust': 11.61, 'speed': 11.18}}
# City Name: Tevaitoa, City ID: 4033375
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': -17.3667, 'lon': 27.15},
#  'dt': 1627403963,
#  'id': 908718,
#  'main': {'feels_like': 55.81,
#           'grnd_level': 932,
#           'humidity': 55,
#           'pressure': 1022,
#           'sea_level': 1022,
#           'temp': 57.76,
#           'temp_max': 57.76,
#           'temp_min': 57.76},
#  'name': 'Maamba',
#  'sys': {'country': 'ZM', 'sunrise': 1627360744, 'sunset': 1627401390},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 351, 'gust': 3.87, 'speed': 3.18}}
# City Name: Maamba, City ID: 908718
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 4.8699, 'lon': -2.2405},
#  'dt': 1627403963,
#  'id': 2303611,
#  'main': {'feels_like': 79.14,
#           'grnd_level': 1010,
#           'humidity': 68,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 79.14,
#           'temp_max': 79.14,
#           'temp_min': 79.14},
#  'name': 'Esim',
#  'sys': {'country': 'GH', 'sunrise': 1627365902, 'sunset': 1627410340},
#  'timezone': 0,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 224, 'gust': 10.29, 'speed': 8.81}}
# City Name: Esim, City ID: 2303611
# {'base': 'stations',
#  'clouds': {'all': 3},
#  'cod': 200,
#  'coord': {'lat': 48.9329, 'lon': -125.5528},
#  'dt': 1627403888,
#  'id': 6171633,
#  'main': {'feels_like': 58.53,
#           'humidity': 93,
#           'pressure': 1018,
#           'temp': 58.6,
#           'temp_max': 66.96,
#           'temp_min': 57.51},
#  'name': 'Ucluelet',
#  'sys': {'country': 'CA',
#          'id': 19458,
#          'sunrise': 1627390149,
#          'sunset': 1627445282,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 246, 'gust': 3.71, 'speed': 3}}
# City Name: Ucluelet, City ID: 6171633
# {'cod': '404', 'message': 'city not found'}
# The city mys shmidta not found.
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.3973, 'lon': -73.6171},
#  'dt': 1627403678,
#  'id': 5110092,
#  'main': {'feels_like': 89.92,
#           'humidity': 55,
#           'pressure': 1014,
#           'temp': 86.31,
#           'temp_max': 89.74,
#           'temp_min': 81.79},
#  'name': 'Brewster',
#  'sys': {'country': 'US',
#          'id': 2002189,
#          'sunrise': 1627379084,
#          'sunset': 1627431418,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 303, 'gust': 3, 'speed': 1.01}}
# City Name: Brewster, City ID: 5110092
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': -38.5473, 'lon': -58.7368},
#  'dt': 1627403723,
#  'id': 3430443,
#  'main': {'feels_like': 37.06,
#           'grnd_level': 1013,
#           'humidity': 82,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 46.04,
#           'temp_max': 46.04,
#           'temp_min': 46.04},
#  'name': 'Necochea',
#  'sys': {'country': 'AR',
#          'id': 2010353,
#          'sunrise': 1627383650,
#          'sunset': 1627419709,
#          'type': 2},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 206, 'gust': 36.48, 'speed': 27.4}}
# City Name: Necochea, City ID: 3430443
# {'base': 'stations',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': -46.2817, 'lon': 169.8464},
#  'dt': 1627403963,
#  'id': 2208248,
#  'main': {'feels_like': 43.07,
#           'grnd_level': 1008,
#           'humidity': 65,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 45.93,
#           'temp_max': 45.93,
#           'temp_min': 45.93},
#  'name': 'Kaitangata',
#  'sys': {'country': 'NZ',
#          'id': 2000217,
#          'sunrise': 1627416373,
#          'sunset': 1627450066,
#          'type': 2},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 281, 'gust': 14.92, 'speed': 5.57}}
# City Name: Kaitangata, City ID: 2208248
# {'base': 'stations',
#  'clouds': {'all': 70},
#  'cod': 200,
#  'coord': {'lat': 19.7297, 'lon': -155.09},
#  'dt': 1627403519,
#  'id': 5855927,
#  'main': {'feels_like': 74.16,
#           'humidity': 95,
#           'pressure': 1017,
#           'temp': 72.72,
#           'temp_max': 73.11,
#           'temp_min': 71.26},
#  'name': 'Hilo',
#  'rain': {'1h': 3.05},
#  'sys': {'country': 'US',
#          'id': 2002460,
#          'sunrise': 1627401270,
#          'sunset': 1627448339,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'moderate rain',
#               'icon': '10d',
#               'id': 501,
#               'main': 'Rain'}],
#  'wind': {'deg': 28, 'gust': 4.52, 'speed': 2.13}}
# City Name: Hilo, City ID: 5855927
# {'base': 'stations',
#  'clouds': {'all': 98},
#  'cod': 200,
#  'coord': {'lat': 15.451, 'lon': 36.4},
#  'dt': 1627403964,
#  'id': 372753,
#  'main': {'feels_like': 85.17,
#           'grnd_level': 954,
#           'humidity': 68,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 81.52,
#           'temp_max': 81.52,
#           'temp_min': 81.52},
#  'name': 'Kassala',
#  'sys': {'country': 'SD', 'sunrise': 1627355702, 'sunset': 1627401992},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 233, 'gust': 4.21, 'speed': 2.95}}
# City Name: Kassala, City ID: 372753
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 21.3156, 'lon': -158.0072},
#  'dt': 1627403964,
#  'id': 5855051,
#  'main': {'feels_like': 76.66,
#           'humidity': 69,
#           'pressure': 1016,
#           'temp': 76.1,
#           'temp_max': 77.09,
#           'temp_min': 75.02},
#  'name': '‘Ewa Beach',
#  'sys': {'country': 'US',
#          'id': 47742,
#          'sunrise': 1627401816,
#          'sunset': 1627449193,
#          'type': 2},
#  'timezone': -36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 60, 'speed': 11.99}}
# City Name: ‘Ewa Beach, City ID: 5855051
# {'base': 'stations',
#  'clouds': {'all': 83},
#  'cod': 200,
#  'coord': {'lat': 35.7333, 'lon': 140.8333},
#  'dt': 1627403765,
#  'id': 2112802,
#  'main': {'feels_like': 73.94,
#           'grnd_level': 999,
#           'humidity': 74,
#           'pressure': 1000,
#           'sea_level': 1000,
#           'temp': 73.42,
#           'temp_max': 73.8,
#           'temp_min': 72.28},
#  'name': 'Hasaki',
#  'sys': {'country': 'JP',
#          'id': 7955,
#          'sunrise': 1627414867,
#          'sunset': 1627465499,
#          'type': 1},
#  'timezone': 32400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 228, 'gust': 13.04, 'speed': 10.25}}
# City Name: Hasaki, City ID: 2112802
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.6789, 'lon': 156.125},
#  'dt': 1627403964,
#  'id': 2121385,
#  'main': {'feels_like': 56.61,
#           'grnd_level': 1008,
#           'humidity': 97,
#           'pressure': 1009,
#           'sea_level': 1009,
#           'temp': 56.68,
#           'temp_max': 56.68,
#           'temp_min': 56.68},
#  'name': "Severo-Kuril'sk",
#  'sys': {'country': 'RU', 'sunrise': 1627408565, 'sunset': 1627464461},
#  'timezone': 39600,
#  'visibility': 206,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 248, 'gust': 15.19, 'speed': 8.93}}
# City Name: Severo-Kuril'sk, City ID: 2121385
# {'base': 'stations',
#  'clouds': {'all': 57},
#  'cod': 200,
#  'coord': {'lat': -41.8697, 'lon': -73.8203},
#  'dt': 1627403965,
#  'id': 3899695,
#  'main': {'feels_like': 44.74,
#           'grnd_level': 1028,
#           'humidity': 64,
#           'pressure': 1034,
#           'sea_level': 1034,
#           'temp': 45.93,
#           'temp_max': 45.93,
#           'temp_min': 45.93},
#  'name': 'Ancud',
#  'sys': {'country': 'CL',
#          'id': 8512,
#          'sunrise': 1627387747,
#          'sunset': 1627422852,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 192, 'gust': 7.54, 'speed': 3.33}}
# City Name: Ancud, City ID: 3899695
# {'cod': '404', 'message': 'city not found'}
# The city bargal not found.
# {'base': 'stations',
#  'clouds': {'all': 37},
#  'cod': 200,
#  'coord': {'lat': 42.7762, 'lon': -9.0603},
#  'dt': 1627403965,
#  'id': 3115824,
#  'main': {'feels_like': 73.54,
#           'grnd_level': 1014,
#           'humidity': 67,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 73.36,
#           'temp_max': 76.68,
#           'temp_min': 68.85},
#  'name': 'Muros',
#  'sys': {'country': 'ES',
#          'id': 72671,
#          'sunrise': 1627363352,
#          'sunset': 1627416163,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 333, 'gust': 20, 'speed': 16.22}}
# City Name: Muros, City ID: 3115824
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 47.674, 'lon': -122.1215},
#  'dt': 1627403767,
#  'id': 5808079,
#  'main': {'feels_like': 70.11,
#           'humidity': 69,
#           'pressure': 1017,
#           'temp': 70.14,
#           'temp_max': 76.33,
#           'temp_min': 62.69},
#  'name': 'Redmond',
#  'sys': {'country': 'US',
#          'id': 2016501,
#          'sunrise': 1627389592,
#          'sunset': 1627444192,
#          'type': 2},
#  'timezone': -25200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 14, 'gust': 5.01, 'speed': 1.01}}
# City Name: Redmond, City ID: 5808079
# {'base': 'stations',
#  'clouds': {'all': 75},
#  'cod': 200,
#  'coord': {'lat': 70.4692, 'lon': -68.5914},
#  'dt': 1627403800,
#  'id': 5924351,
#  'main': {'feels_like': 48.52,
#           'humidity': 76,
#           'pressure': 1003,
#           'temp': 50.23,
#           'temp_max': 50.23,
#           'temp_min': 50.23},
#  'name': 'Clyde River',
#  'sys': {'country': 'CA', 'id': 776, 'sunrise': 0, 'sunset': 0, 'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 250, 'speed': 4.61}}
# City Name: Clyde River, City ID: 5924351
# {'cod': '404', 'message': 'city not found'}
# The city ruatoria not found.
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 21.4612, 'lon': -71.1419},
#  'dt': 1627403774,
#  'id': 3576994,
#  'main': {'feels_like': 94.98,
#           'humidity': 70,
#           'pressure': 1018,
#           'temp': 85.96,
#           'temp_max': 85.96,
#           'temp_min': 85.96},
#  'name': 'Cockburn Town',
#  'sys': {'country': 'TC',
#          'id': 7041,
#          'sunrise': 1627380948,
#          'sunset': 1627428366,
#          'type': 1},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 80, 'speed': 17.27}}
# City Name: Cockburn Town, City ID: 3576994
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 42.097, 'lon': -79.2353},
#  'dt': 1627403961,
#  'id': 5122534,
#  'main': {'feels_like': 83.66,
#           'humidity': 51,
#           'pressure': 1015,
#           'temp': 82.65,
#           'temp_max': 84.09,
#           'temp_min': 78.39},
#  'name': 'Jamestown',
#  'sys': {'country': 'US',
#          'id': 2008828,
#          'sunrise': 1627380320,
#          'sunset': 1627432879,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 250, 'gust': 13, 'speed': 7}}
# City Name: Jamestown, City ID: 5122534
# {'base': 'stations',
#  'clouds': {'all': 19},
#  'cod': 200,
#  'coord': {'lat': -0.9492, 'lon': 100.3543},
#  'dt': 1627403965,
#  'id': 1633419,
#  'main': {'feels_like': 78.85,
#           'grnd_level': 1011,
#           'humidity': 88,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 78.85,
#           'temp_max': 78.85,
#           'temp_min': 78.85},
#  'name': 'Padang',
#  'sys': {'country': 'ID',
#          'id': 9423,
#          'sunrise': 1627341766,
#          'sunset': 1627385230,
#          'type': 1},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 92, 'gust': 3.33, 'speed': 3.4}}
# City Name: Padang, City ID: 1633419
# {'base': 'stations',
#  'clouds': {'all': 70},
#  'cod': 200,
#  'coord': {'lat': 71.9667, 'lon': 102.5},
#  'dt': 1627403966,
#  'id': 2022572,
#  'main': {'feels_like': 74.19,
#           'grnd_level': 998,
#           'humidity': 57,
#           'pressure': 1001,
#           'sea_level': 1001,
#           'temp': 74.37,
#           'temp_max': 74.37,
#           'temp_min': 74.37},
#  'name': 'Khatanga',
#  'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 124, 'gust': 22.08, 'speed': 11.12}}
# City Name: Khatanga, City ID: 2022572
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': -33.9258, 'lon': 18.4232},
#  'dt': 1627403966,
#  'id': 3369157,
#  'main': {'feels_like': 55.67,
#           'humidity': 85,
#           'pressure': 1017,
#           'temp': 56.34,
#           'temp_max': 58.26,
#           'temp_min': 54.1},
#  'name': 'Cape Town',
#  'rain': {'1h': 6.86},
#  'sys': {'country': 'ZA',
#          'id': 2033665,
#          'sunrise': 1627364547,
#          'sunset': 1627401775,
#          'type': 2},
#  'timezone': 7200,
#  'visibility': 1500,
#  'weather': [{'description': 'heavy intensity rain',
#               'icon': '10n',
#               'id': 502,
#               'main': 'Rain'}],
#  'wind': {'deg': 315, 'gust': 11.01, 'speed': 4}}
# City Name: Cape Town, City ID: 3369157
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.3712, 'lon': -73.414},
#  'dt': 1627403966,
#  'id': 5282297,
#  'main': {'feels_like': 89.46,
#           'humidity': 55,
#           'pressure': 1014,
#           'temp': 86.04,
#           'temp_max': 90.16,
#           'temp_min': 81.55},
#  'name': 'Bethel',
#  'sys': {'country': 'US',
#          'id': 2004826,
#          'sunrise': 1627379040,
#          'sunset': 1627431365,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 161, 'gust': 5.99, 'speed': 1.99}}
# City Name: Bethel, City ID: 5282297
# {'base': 'stations',
#  'clouds': {'all': 28},
#  'cod': 200,
#  'coord': {'lat': -9.8, 'lon': -139.0333},
#  'dt': 1627403860,
#  'id': 4020109,
#  'main': {'feels_like': 78.64,
#           'grnd_level': 1007,
#           'humidity': 72,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 77.77,
#           'temp_max': 77.77,
#           'temp_min': 77.77},
#  'name': 'Atuona',
#  'rain': {'1h': 0.22},
#  'sys': {'country': 'PF', 'sunrise': 1627399959, 'sunset': 1627441943},
#  'timezone': -34200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 94, 'gust': 21.05, 'speed': 20.15}}
# City Name: Atuona, City ID: 4020109
# {'base': 'stations',
#  'clouds': {'all': 30},
#  'cod': 200,
#  'coord': {'lat': -17.7333, 'lon': -149.15},
#  'dt': 1627403967,
#  'id': 4033557,
#  'main': {'feels_like': 76.06,
#           'grnd_level': 1015,
#           'humidity': 77,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 75.22,
#           'temp_max': 75.22,
#           'temp_min': 75},
#  'name': 'Tautira',
#  'sys': {'country': 'PF',
#          'id': 7318,
#          'sunrise': 1627403080,
#          'sunset': 1627443678,
#          'type': 1},
#  'timezone': -36000,
#  'visibility': 10000,
# ...
#           'sea_level': 996,
#           'temp': 81.73,
#           'temp_max': 81.73,
#           'temp_min': 80.28},
#  'name': 'Ninghai',
#  'rain': {'1h': 0.37},
#  'sys': {'country': 'CN',
#          'id': 2016515,
#          'sunrise': 1627420319,
#          'sunset': 1627469362,
#          'type': 2},
#  'timezone': 28800,
#  'visibility': 5149,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 151, 'gust': 24.58, 'speed': 10.42}}
# City Name: Ninghai, City ID: 1799384
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 43.801, 'lon': 87.6005},
#  'dt': 1627404088,
#  'id': 1529102,
#  'main': {'feels_like': 82.99,
#           'humidity': 30,
#           'pressure': 1003,
#           'temp': 85.15,
#           'temp_max': 85.15,
#           'temp_min': 85.15},
#  'name': 'Ürümqi',
#  'sys': {'country': 'CN',
#          'id': 9677,
#          'sunrise': 1627426423,
#          'sunset': 1627479495,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 280, 'speed': 6.71}}
# City Name: Ürümqi, City ID: 1529102
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 65.5833, 'lon': -171},
#  'dt': 1627404088,
#  'id': 4031637,
#  'main': {'feels_like': 39.87,
#           'grnd_level': 995,
#           'humidity': 99,
#           'pressure': 997,
#           'sea_level': 997,
#           'temp': 43.59,
#           'temp_max': 43.59,
#           'temp_min': 43.59},
#  'name': 'Lavrentiya',
#  'rain': {'1h': 0.98},
#  'sys': {'country': 'RU', 'sunrise': 1627480943, 'sunset': 1627549102},
#  'timezone': 43200,
#  'visibility': 145,
#  'weather': [{'description': 'light rain',
#               'icon': '10n',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 189, 'gust': 8.79, 'speed': 6.29}}
# City Name: Lavrentiya, City ID: 4031637
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -28.8667, 'lon': 153.5667},
#  'dt': 1627404088,
#  'id': 2177069,
#  'main': {'feels_like': 50.83,
#           'humidity': 94,
#           'pressure': 1017,
#           'temp': 51.55,
#           'temp_max': 53.56,
#           'temp_min': 41.04},
#  'name': 'Ballina',
#  'sys': {'country': 'AU',
#          'id': 9496,
#          'sunrise': 1627417913,
#          'sunset': 1627456340,
#          'type': 1},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 20, 'speed': 5.75}}
# City Name: Ballina, City ID: 2177069
# {'base': 'stations',
#  'clouds': {'all': 20},
#  'cod': 200,
#  'coord': {'lat': 29.6994, 'lon': -91.2068},
#  'dt': 1627404088,
#  'id': 4333811,
#  'main': {'feels_like': 101.01,
#           'humidity': 74,
#           'pressure': 1017,
#           'temp': 88.41,
#           'temp_max': 91.04,
#           'temp_min': 87.01},
#  'name': 'Morgan City',
#  'sys': {'country': 'US',
#          'id': 5422,
#          'sunrise': 1627384889,
#          'sunset': 1627434056,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 4.61}}
# City Name: Morgan City, City ID: 4333811
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 24.5133, 'lon': 117.6556},
#  'dt': 1627404089,
#  'id': 1785018,
#  'main': {'feels_like': 94.33,
#           'grnd_level': 994,
#           'humidity': 80,
#           'pressure': 996,
#           'sea_level': 996,
#           'temp': 84.13,
#           'temp_max': 84.13,
#           'temp_min': 84.13},
#  'name': 'Zhangzhou',
#  'sys': {'country': 'CN',
#          'id': 9649,
#          'sunrise': 1627421741,
#          'sunset': 1627469750,
#          'type': 1},
#  'timezone': 28800,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04n',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 277, 'gust': 1.68, 'speed': 1.45}}
# City Name: Zhangzhou, City ID: 1785018
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 50.012, 'lon': 1.5176},
#  'dt': 1627404089,
#  'id': 3034366,
#  'main': {'feels_like': 68.54,
#           'grnd_level': 1008,
#           'humidity': 91,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 67.78,
#           'temp_max': 70.39,
#           'temp_min': 63.32},
#  'name': 'Beauchamps',
#  'rain': {'1h': 0.12},
#  'sys': {'country': 'FR',
#          'id': 6449,
#          'sunrise': 1627359380,
#          'sunset': 1627415057,
#          'type': 1},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'light rain',
#               'icon': '10d',
#               'id': 500,
#               'main': 'Rain'}],
#  'wind': {'deg': 204, 'gust': 19.1, 'speed': 11.07}}
# City Name: Beauchamps, City ID: 3034366
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 39.0062, 'lon': -77.4286},
#  'dt': 1627404051,
#  'id': 4787534,
#  'main': {'feels_like': 93.51,
#           'humidity': 46,
#           'pressure': 1018,
#           'temp': 90.36,
#           'temp_max': 94.12,
#           'temp_min': 85.33},
#  'name': 'Sterling',
#  'sys': {'country': 'US',
#          'id': 2004257,
#          'sunrise': 1627380369,
#          'sunset': 1627431962,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 110, 'gust': 5.99, 'speed': 1.99}}
# City Name: Sterling, City ID: 4787534
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': -14.6585, 'lon': 17.691},
#  'dt': 1627404089,
#  'id': 3347353,
#  'main': {'feels_like': 59.88,
#           'grnd_level': 868,
#           'humidity': 25,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 62.73,
#           'temp_max': 62.73,
#           'temp_min': 62.73},
#  'name': 'Menongue',
#  'sys': {'country': 'AO', 'sunrise': 1627362771, 'sunset': 1627403903},
#  'timezone': 3600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 98, 'gust': 5.53, 'speed': 5.57}}
# City Name: Menongue, City ID: 3347353
# {'base': 'stations',
#  'clouds': {'all': 5},
#  'cod': 200,
#  'coord': {'lat': 1, 'lon': -52},
#  'dt': 1627404033,
#  'id': 3407762,
#  'main': {'feels_like': 91.18,
#           'grnd_level': 997,
#           'humidity': 58,
#           'pressure': 1013,
#           'sea_level': 1013,
#           'temp': 86.43,
#           'temp_max': 86.43,
#           'temp_min': 86.43},
#  'name': 'Amapá',
#  'sys': {'country': 'BR', 'sunrise': 1627378169, 'sunset': 1627421957},
#  'timezone': -10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 79, 'gust': 6.78, 'speed': 3.91}}
# City Name: Amapá, City ID: 3407762
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 60.0973, 'lon': 19.9348},
#  'dt': 1627404089,
#  'id': 3041732,
#  'main': {'feels_like': 80.91,
#           'humidity': 47,
#           'pressure': 1012,
#           'temp': 80.46,
#           'temp_max': 80.46,
#           'temp_min': 80.46},
#  'name': 'Mariehamn',
#  'sys': {'country': 'AX',
#          'id': 1347,
#          'sunrise': 1627351728,
#          'sunset': 1627413869,
#          'type': 1},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 130, 'speed': 9.22}}
# City Name: Mariehamn, City ID: 3041732
# {'base': 'stations',
#  'clouds': {'all': 95},
#  'cod': 200,
#  'coord': {'lat': -37.8811, 'lon': 147.981},
#  'dt': 1627404090,
#  'id': 2160735,
#  'main': {'feels_like': 61.39,
#           'grnd_level': 999,
#           'humidity': 47,
#           'pressure': 1000,
#           'sea_level': 1000,
#           'temp': 63.18,
#           'temp_max': 63.18,
#           'temp_min': 61.57},
#  'name': 'Lakes Entrance',
#  'sys': {'country': 'AU',
#          'id': 2011895,
#          'sunrise': 1627420327,
#          'sunset': 1627456608,
#          'type': 2},
#  'timezone': 36000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 326, 'gust': 31.47, 'speed': 11.65}}
# City Name: Lakes Entrance, City ID: 2160735
# {'base': 'stations',
#  'clouds': {'all': 10},
#  'cod': 200,
#  'coord': {'lat': -9.8756, 'lon': -56.0861},
#  'dt': 1627404090,
#  'id': 6316343,
#  'main': {'feels_like': 95.29,
#           'grnd_level': 980,
#           'humidity': 19,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 98.51,
#           'temp_max': 98.51,
#           'temp_min': 98.51},
#  'name': 'Alta Floresta',
#  'sys': {'country': 'BR', 'sunrise': 1627380060, 'sunset': 1627422027},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 109, 'gust': 5.21, 'speed': 3.09}}
# City Name: Alta Floresta, City ID: 6316343
# {'base': 'stations',
#  'clouds': {'all': 24},
#  'cod': 200,
#  'coord': {'lat': -36.8333, 'lon': 175.7},
#  'dt': 1627404090,
#  'id': 2179103,
#  'main': {'feels_like': 45.61,
#           'grnd_level': 1014,
#           'humidity': 84,
#           'pressure': 1015,
#           'sea_level': 1015,
#           'temp': 49.01,
#           'temp_max': 49.01,
#           'temp_min': 49.01},
#  'name': 'Whitianga',
#  'sys': {'country': 'NZ',
#          'id': 2002961,
#          'sunrise': 1627413540,
#          'sunset': 1627450090,
#          'type': 2},
#  'timezone': 43200,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02n',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 245, 'gust': 22.7, 'speed': 7.9}}
# City Name: Whitianga, City ID: 2179103
# {'base': 'stations',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': 14.2, 'lon': 24.6667},
#  'dt': 1627404090,
#  'id': 371745,
#  'main': {'feels_like': 78.13,
#           'grnd_level': 886,
#           'humidity': 61,
#           'pressure': 1010,
#           'sea_level': 1010,
#           'temp': 77.79,
#           'temp_max': 77.79,
#           'temp_min': 77.79},
#  'name': 'Kutum',
#  'sys': {'country': 'SD', 'sunrise': 1627358632, 'sunset': 1627404694},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 151, 'gust': 11.18, 'speed': 9.37}}
# City Name: Kutum, City ID: 371745
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.8068, 'lon': -74.1854},
#  'dt': 1627404085,
#  'id': 5095779,
#  'main': {'feels_like': 91.04,
#           'humidity': 46,
#           'pressure': 1014,
#           'temp': 88.88,
#           'temp_max': 92.88,
#           'temp_min': 83.64},
#  'name': 'Bloomfield',
#  'sys': {'country': 'US',
#          'id': 2004932,
#          'sunrise': 1627379315,
#          'sunset': 1627431460,
#          'type': 2},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'haze', 'icon': '50d', 'id': 721, 'main': 'Haze'}],
#  'wind': {'deg': 32, 'gust': 7, 'speed': 1.99}}
# City Name: Bloomfield, City ID: 5095779
# {'cod': '404', 'message': 'city not found'}
# The city rungata not found.
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 64.8989, 'lon': 45.7622},
#  'dt': 1627403953,
#  'id': 535839,
#  'main': {'feels_like': 42.71,
#           'grnd_level': 1010,
#           'humidity': 75,
#           'pressure': 1016,
#           'sea_level': 1016,
#           'temp': 47.19,
#           'temp_max': 47.19,
#           'temp_min': 47.19},
#  'name': 'Leshukonskoye',
#  'sys': {'country': 'RU', 'sunrise': 1627342713, 'sunset': 1627410487},
#  'timezone': 10800,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 320, 'gust': 17.11, 'speed': 9.6}}
# City Name: Leshukonskoye, City ID: 535839
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': 59.0556, 'lon': 80.8572},
#  'dt': 1627404091,
#  'id': 1504382,
#  'main': {'feels_like': 55.98,
#           'grnd_level': 1000,
#           'humidity': 66,
#           'pressure': 1006,
#           'sea_level': 1006,
#           'temp': 57.43,
#           'temp_max': 57.43,
#           'temp_min': 57.43},
#  'name': 'Kargasok',
#  'sys': {'country': 'RU', 'sunrise': 1627337535, 'sunset': 1627398820},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04n',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 228, 'gust': 14.61, 'speed': 6.49}}
# City Name: Kargasok, City ID: 1504382
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -20.15, 'lon': 28.5833},
#  'dt': 1627404091,
#  'id': 894701,
#  'main': {'feels_like': 50.67,
#           'grnd_level': 873,
#           'humidity': 33,
#           'pressure': 1023,
#           'sea_level': 1023,
#           'temp': 54.01,
#           'temp_max': 54.01,
#           'temp_min': 54.01},
#  'name': 'Bulawayo',
#  'sys': {'country': 'ZW', 'sunrise': 1627360657, 'sunset': 1627400789},
#  'timezone': 7200,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01n',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 117, 'gust': 18.7, 'speed': 7.81}}
# City Name: Bulawayo, City ID: 894701
# {'cod': '404', 'message': 'city not found'}
# The city tuggurt not found.
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 20.931, 'lon': -17.0347},
#  'dt': 1627404091,
#  'id': 2377457,
#  'main': {'feels_like': 77.63,
#           'humidity': 69,
#           'pressure': 1009,
#           'temp': 76.98,
#           'temp_max': 76.98,
#           'temp_min': 76.98},
#  'name': 'Nouadhibou',
#  'sys': {'country': 'MR',
#          'id': 2444,
#          'sunrise': 1627368011,
#          'sunset': 1627415332,
#          'type': 1},
#  'timezone': 0,
#  'visibility': 6000,
#  'weather': [{'description': 'sand', 'icon': '50d', 'id': 751, 'main': 'Sand'}],
#  'wind': {'deg': 340, 'speed': 21.85}}
# City Name: Nouadhibou, City ID: 2377457
# {'base': 'stations',
#  'clouds': {'all': 26},
#  'cod': 200,
#  'coord': {'lat': 9.9347, 'lon': 106.3453},
#  'dt': 1627404092,
#  'id': 1563926,
#  'main': {'feels_like': 79.05,
#           'grnd_level': 1007,
#           'humidity': 87,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 79.05,
#           'temp_max': 79.05,
#           'temp_min': 79.05},
#  'name': 'Tra Vinh',
#  'sys': {'country': 'VN', 'sunrise': 1627339405, 'sunset': 1627384716},
#  'timezone': 25200,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03n',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 240, 'gust': 24.7, 'speed': 7.85}}
# City Name: Tra Vinh, City ID: 1563926
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': -35.3333, 'lon': -72.4167},
#  'dt': 1627403941,
#  'id': 3893726,
#  'main': {'feels_like': 50.45,
#           'grnd_level': 1022,
#           'humidity': 49,
#           'pressure': 1025,
#           'sea_level': 1025,
#           'temp': 53.13,
#           'temp_max': 53.13,
#           'temp_min': 53.13},
#  'name': 'Constitución',
#  'sys': {'country': 'CL', 'sunrise': 1627386511, 'sunset': 1627423415},
#  'timezone': -14400,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 191, 'gust': 15.23, 'speed': 9.4}}
# City Name: Constitución, City ID: 3893726

# %% [markdown]
# ## Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame({"City": city_name,
                       "ID": city_id,
                        "Country" : country_name,
                       "Cloudiness": cloudiness,
                       "Temperature": temperature, "Max Temperature": max_temperature,
                       "Latitude": lat,
                       "Longitude": long,
                       "Humidity": humidity,
                       "Wind Speed": wind_speed})

city_df.to_csv(output_data_file, header=True, index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_indices = city_df.index[city_df['Humidity'] > 100].tolist()
humidity_indices
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
city_clean_df = city_df.drop(humidity_indices)
city_clean_df.head()
# Out:
#            City       ID Country  Cloudiness  Temperature  Max Temperature  \
# 0      Souillac   933995      MU          75        66.58            66.58
# 1        Vostok  2013279      RU          93        70.75            70.75
# 2  Saint George  5546220      US           1        82.60            87.53
# 3        Dikson  1507390      RU         100        56.12            56.12
# 4       Ushuaia  3833367      AR          90        37.06            37.06
#
#    Latitude  Longitude  Humidity  Wind Speed
# 0  -20.5167    57.5167        94        8.05
# 1   46.4856   135.8833        84        3.13
# 2   37.1041  -113.5841        63        1.99
# 3   73.5069    80.5464        89       16.91
# 4  -54.8000   -68.3000        87        0.00

# %%
#verify the original data not touched
city_df.head()
# Out:
#            City       ID Country  Cloudiness  Temperature  Max Temperature  \
# 0      Souillac   933995      MU          75        66.58            66.58
# 1        Vostok  2013279      RU          93        70.75            70.75
# 2  Saint George  5546220      US           1        82.60            87.53
# 3        Dikson  1507390      RU         100        56.12            56.12
# 4       Ushuaia  3833367      AR          90        37.06            37.06
#
#    Latitude  Longitude  Humidity  Wind Speed
# 0  -20.5167    57.5167        94        8.05
# 1   46.4856   135.8833        84        3.13
# 2   37.1041  -113.5841        63        1.99
# 3   73.5069    80.5464        89       16.91
# 4  -54.8000   -68.3000        87        0.00

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(city_df["Latitude"], city_df["Temperature"])
plt.title("Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.grid()
plt.savefig("../WeatherPy/Images/Latitude vs Temperature.png")

# %%
# #What is the code analyzing?
# Purpose of this plot is to logically observe a trend of temperature with latitude. 
# This scatter of randomly selected data shows that temperature rises closer to the equator.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_df["Latitude"], city_df["Humidity"])
plt.title("Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("../WeatherPy/Images/Latitude vs Humidity.png")

# %%
# #What is the code analyzing?
# Since the percentage of humidity affects temperature and therefore measures temperature indirectly,
# plotting latitude and humidity will show the relationship of weather as latitude is closer to the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_df["Latitude"], city_df["Cloudiness"])
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid()
plt.savefig("../WeatherPy/Images/Latitude vs Cloudiness.png")

# %%
# #What is the code analyzing?
# Due to the scientific facts that tell us winds push water vapor towards the equator,
# this plot aims to prove the fact using data.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_df["Latitude"], city_df["Wind Speed"])
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("../WeatherPy/Images/Latitude vs Wind Speed.png")

# %%
# #What is the code analyzing?
# Generally, it is known that wind speed is higher along the poles. 
# The aim of this plot is to observe data that supports the fact and to show that the temperature is lower at the poles.

# %% [markdown]
# ## Linear Regression

# %%
nor = city_df['Latitude'] >=0
sou = city_df['Latitude'] <0
nor_hemis = city_df[nor]
#nor_hemis.head()
sou_hemis = city_df[sou]
#sou_hemis.head()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = nor_hemis["Latitude"]
y_values = nor_hemis["Max Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(slope) + "x + " + str(intercept)
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values, y_values)
plt.title('Temperature vs Latitude at Northern Hemisphere')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,40))
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.show()

# %%
# #analysis
# As observed in the scatter in the beginning, linear regression here shows the temperature decreases away from the equator. 
# The slope is negative, supporting the fact that temperature is lower at the northern pole than at the equator.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = sou_hemis["Latitude"]
y_values = sou_hemis["Max Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(slope) + "x + " + str(intercept)
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values, y_values)
plt.title('Temperature vs Latitude at Southern Hemisphere')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,90))
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.show()

# %%
### analysis
# This plot shows that as the latitude is farther from the sourthern hemisphere, the temperature increases. 
# The slope is about 0.80 which is close to 1, suggesting that the relationship is a strong
# incline in temperature as the latitude is closer to 0.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = nor_hemis["Latitude"]
y_values = nor_hemis["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(slope) + "x + " + str(intercept)
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values, y_values)
plt.title('Humidity vs Latitude at Northern Hemisphere')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10))
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

# %%
###analysis
#My theory before plotting this scatter and regression line was that humidity would be lower closer to the northern pole.
#Although this regression line does not show a strong relationship between humidity and latitude, it does suggest a possible 
#increase in humidity closer to the northern pole.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = sou_hemis["Latitude"]
y_values = sou_hemis["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(slope) + "x + " + str(intercept)
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values, y_values)
plt.title('Humidity vs Latitude at Southern Hemisphere')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10))
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.show()

# %%
###analysis
#This linear regression line (slope = 0.05) shows that there is a very poor relationship between humidity and latitide.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = nor_hemis["Latitude"]
y_values = nor_hemis["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(slope) + "x + " + str(intercept)
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values, y_values)
plt.title('Cloudiness vs Latitude at Northern Hemisphere')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %%
###analysis
#My hypothesis was there would be more clouds at the northern pole than at the equator. 
#This linear regression shows no strong evidence of a relationship between the two variables.
#Therefore, no reliable conclusion could be drawn based on this plot.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = sou_hemis["Latitude"]
y_values = sou_hemis["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(slope) + "x + " + str(intercept)
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values, y_values)
plt.title('Cloudiness vs Latitude at Southern Hemisphere')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.show()

# %%
###analysis
#This linear regression shows a strong negative relationship between Cloudiness and latitude 
#suggesting that there more clouds at the sourthern pole than at the equator.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = nor_hemis["Latitude"]
y_values = nor_hemis["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(slope) + "x + " + str(intercept)
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values, y_values)
plt.title('Wind Speed vs Latitude at Northern Hemisphere')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,25))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %%
###analysis
#Wind speed and latitude had no assumed relationship previous to this plot. 
#But this regression line shows a faint relationship suggesting 
#there is a higher wind speed away from the northern pole than at the equator.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = sou_hemis["Latitude"]
y_values = sou_hemis["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(slope) + "x + " + str(intercept)
correlation = st.pearsonr(x_values, y_values)

plt.scatter(x_values, y_values)
plt.title('Wind Speed vs Latitude at Southern Hemisphere')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,20))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.show()

# %%
###analysis
#Similar to the northern pole, this regression line shows that there is a weak relationship suggesting that wind speed is higher
#at the southern pole than at the equator.
